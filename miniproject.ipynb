# %% [markdown]
# ## Project
# In this project, you will perform EDA, visualize and make calculations from African food prices data using matplotlib, seaborn, and pandas. The dataset values were obtained from the Source above.

# %% [markdown]
# ### Perform Data Cleaning and Transformation

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
print('done')
# Out:
# done

# %%
afp = pd.read_csv("datasets/africa_food_prices.csv")
afp.head()
# Out:
#    Unnamed: 0  country_id  country  state_id  state  market_id   market  \
# 0       15427         4.0  Algeria       344  Alger       1794  Algiers
# 1       15428         4.0  Algeria       344  Alger       1794  Algiers
# 2       15429         4.0  Algeria       344  Alger       1794  Algiers
# 3       15430         4.0  Algeria       344  Alger       1794  Algiers
# 4       15431         4.0  Algeria       344  Alger       1794  Algiers
#
#    produce_id        produce  currency_id currency  pt_id market_type  \
# 0          52  Rice - Retail          0.0      DZD     15      Retail
# 1          52  Rice - Retail          0.0      DZD     15      Retail
# 2          52  Rice - Retail          0.0      DZD     15      Retail
# 3          52  Rice - Retail          0.0      DZD     15      Retail
# 4          52  Rice - Retail          0.0      DZD     15      Retail
#
#    um_unit_id quantity  month  year  price  mp_commoditysource
# ...

# %%
afp.columns
# Out:
# Index(['Unnamed: 0', 'country_id', 'country', 'state_id', 'state', 'market_id',
#        'market', 'produce_id', 'produce', 'currency_id', 'currency', 'pt_id',
#        'market_type', 'um_unit_id', 'quantity', 'month', 'year', 'price',
#        'mp_commoditysource'],
#       dtype='object')

# %%
afp.duplicated()
# Out:
# 0         False
# 1         False
# 2         False
# 3         False
# 4         False
#           ...
# 956774    False
# 956775    False
# 956776    False
# 956777    False
# 956778    False
# Length: 956779, dtype: bool

# %%
afp.drop_duplicates()
# Out:
#         Unnamed: 0  country_id   country  state_id     state  market_id  \
# 0            15427         4.0   Algeria       344     Alger       1794
# 1            15428         4.0   Algeria       344     Alger       1794
# 2            15429         4.0   Algeria       344     Alger       1794
# 3            15430         4.0   Algeria       344     Alger       1794
# 4            15431         4.0   Algeria       344     Alger       1794
# ...            ...         ...       ...       ...       ...        ...
# 956774     2050633       271.0  Zimbabwe      3444  Midlands       5594
# 956775     2050634       271.0  Zimbabwe      3444  Midlands       5594
# 956776     2050635       271.0  Zimbabwe      3444  Midlands       5594
# 956777     2050636       271.0  Zimbabwe      3444  Midlands       5594
# 956778     2050637       271.0  Zimbabwe      3444  Midlands       5594
#
#             market  produce_id                  produce  currency_id currency  \
# ...

# %%
missing_values = afp.isnull().sum()
print("Missing Values:\n", missing_values)
# Out:
# Missing Values:
#  Unnamed: 0                 0
# country_id                 0
# country                    0
# state_id                   0
# state                 126678
# market_id                  0
# market                     0
# produce_id                 0
# produce                    0
# currency_id                0
# currency                   0
# pt_id                      0
# market_type                0
# um_unit_id                 0
# quantity                   0
# month                      0
# year                       0
# price                      0
# mp_commoditysource    956779
# dtype: int64

# %%
afp.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 956779 entries, 0 to 956778
# Data columns (total 19 columns):
#  #   Column              Non-Null Count   Dtype
# ---  ------              --------------   -----
#  0   Unnamed: 0          956779 non-null  int64
#  1   country_id          956779 non-null  float64
#  2   country             956779 non-null  object
#  3   state_id            956779 non-null  int64
#  4   state               830101 non-null  object
#  5   market_id           956779 non-null  int64
#  6   market              956779 non-null  object
#  7   produce_id          956779 non-null  int64
#  8   produce             956779 non-null  object
#  9   currency_id         956779 non-null  float64
#  10  currency            956779 non-null  object
#  11  pt_id               956779 non-null  int64
#  12  market_type         956779 non-null  object
#  13  um_unit_id          956779 non-null  int64
#  14  quantity            956779 non-null  object
# ...

# %%
afp[afp["state"].isnull() == True]
# Out:
#         Unnamed: 0  country_id    country  state_id state  market_id  \
# 140847      398362        50.0       Chad         0   NaN       1965
# 140848      398363        50.0       Chad         0   NaN       1965
# 140849      398364        50.0       Chad         0   NaN       1965
# 140850      398365        50.0       Chad         0   NaN       1965
# 140851      398366        50.0       Chad         0   NaN       1965
# ...            ...         ...        ...       ...   ...        ...
# 889628     1713307       235.0  Swaziland      2784   NaN       2654
# 889629     1713308       235.0  Swaziland      2784   NaN       2654
# 889630     1713309       235.0  Swaziland      2784   NaN       2654
# 889631     1713310       235.0  Swaziland      2784   NaN       2654
# 889632     1713311       235.0  Swaziland      2784   NaN       2654
#
#                   market  produce_id                   produce  currency_id  \
# ...

# %%
afp.rename(columns={
    'country id': 'adm0_id',
    'country': 'adm0',
    'market id': 'mkt_id',
    'market': 'mkt',
    'produce id': 'pd_id',
    'produce': 'pd',
    'currency id': 'cur_id',
    'currency': 'cur',
    'market type': 'pt_id',
    'um_unit_id': 'um_name',
    'month': 'mp_month',
    'year': 'mp_year',
    'price': 'mp_price'
}, inplace=True)

# %%
afp.to_csv('cleaned_data.csv', index=False)

# %%
afp
# Out:
#         Unnamed: 0  country_id      adm0  state_id     state  market_id  \
# 0            15427         4.0   Algeria       344     Alger       1794
# 1            15428         4.0   Algeria       344     Alger       1794
# 2            15429         4.0   Algeria       344     Alger       1794
# 3            15430         4.0   Algeria       344     Alger       1794
# 4            15431         4.0   Algeria       344     Alger       1794
# ...            ...         ...       ...       ...       ...        ...
# 956774     2050633       271.0  Zimbabwe      3444  Midlands       5594
# 956775     2050634       271.0  Zimbabwe      3444  Midlands       5594
# 956776     2050635       271.0  Zimbabwe      3444  Midlands       5594
# 956777     2050636       271.0  Zimbabwe      3444  Midlands       5594
# 956778     2050637       271.0  Zimbabwe      3444  Midlands       5594
#
#                mkt  produce_id                       pd  currency_id  cur  \
# ...

# %% [markdown]
# # Perform EDA on the dataset

# %%
print(afp.head())
# Out:
#    Unnamed: 0  country_id     adm0  state_id  state  market_id      mkt  \
# 0       15427         4.0  Algeria       344  Alger       1794  Algiers
# 1       15428         4.0  Algeria       344  Alger       1794  Algiers
# 2       15429         4.0  Algeria       344  Alger       1794  Algiers
# 3       15430         4.0  Algeria       344  Alger       1794  Algiers
# 4       15431         4.0  Algeria       344  Alger       1794  Algiers
#
#    produce_id             pd  currency_id  cur  pt_id market_type  um_name  \
# 0          52  Rice - Retail          0.0  DZD     15      Retail        5
# 1          52  Rice - Retail          0.0  DZD     15      Retail        5
# 2          52  Rice - Retail          0.0  DZD     15      Retail        5
# 3          52  Rice - Retail          0.0  DZD     15      Retail        5
# 4          52  Rice - Retail          0.0  DZD     15      Retail        5
#
#   quantity  mp_month  mp_year  mp_price  mp_commoditysource
# ...

# %%
print(afp.info())
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 956779 entries, 0 to 956778
# Data columns (total 19 columns):
#  #   Column              Non-Null Count   Dtype
# ---  ------              --------------   -----
#  0   Unnamed: 0          956779 non-null  int64
#  1   country_id          956779 non-null  float64
#  2   adm0                956779 non-null  object
#  3   state_id            956779 non-null  int64
#  4   state               830101 non-null  object
#  5   market_id           956779 non-null  int64
#  6   mkt                 956779 non-null  object
#  7   produce_id          956779 non-null  int64
#  8   pd                  956779 non-null  object
#  9   currency_id         956779 non-null  float64
#  10  cur                 956779 non-null  object
#  11  pt_id               956779 non-null  int64
#  12  market_type         956779 non-null  object
#  13  um_name             956779 non-null  int64
#  14  quantity            956779 non-null  object
# ...

# %%
print(afp.describe())
# Out:
#          Unnamed: 0     country_id       state_id      market_id  \
# count  9.567790e+05  956779.000000  956779.000000  956779.000000
# mean   1.076345e+06    1961.192782   22287.911831    1392.594222
# std    5.159597e+05   10404.034922   98565.608270    1027.751212
# min    1.542700e+04       4.000000       0.000000     101.000000
# 25%    5.939185e+05      90.000000    1836.000000     528.000000
# 50%    1.113054e+06     155.000000    2209.000000    1078.000000
# 75%    1.513290e+06     205.000000   21971.000000    2281.000000
# max    2.050637e+06   70001.000000  900003.000000    6081.000000
#
#           produce_id  currency_id          pt_id        um_name  \
# count  956779.000000     956779.0  956779.000000  956779.000000
# mean      186.141214          0.0      14.926716      14.017183
# std       165.401303          0.0       0.263570      24.437728
# min        50.000000          0.0      14.000000       5.000000
# ...

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
afp = pd.read_csv("datasets/africa_food_prices.csv")

# %%
print(afp.head())
# Out:
#    Unnamed: 0  country_id  country  state_id  state  market_id   market  \
# 0       15427         4.0  Algeria       344  Alger       1794  Algiers
# 1       15428         4.0  Algeria       344  Alger       1794  Algiers
# 2       15429         4.0  Algeria       344  Alger       1794  Algiers
# 3       15430         4.0  Algeria       344  Alger       1794  Algiers
# 4       15431         4.0  Algeria       344  Alger       1794  Algiers
#
#    produce_id        produce  currency_id currency  pt_id market_type  \
# 0          52  Rice - Retail          0.0      DZD     15      Retail
# 1          52  Rice - Retail          0.0      DZD     15      Retail
# 2          52  Rice - Retail          0.0      DZD     15      Retail
# 3          52  Rice - Retail          0.0      DZD     15      Retail
# 4          52  Rice - Retail          0.0      DZD     15      Retail
#
#    um_unit_id quantity  month  year  price  mp_commoditysource
# ...

# %%
print(afp.isnull().sum())
# Out:
# Unnamed: 0                 0
# country_id                 0
# country                    0
# state_id                   0
# state                 126678
# market_id                  0
# market                     0
# produce_id                 0
# produce                    0
# currency_id                0
# currency                   0
# pt_id                      0
# market_type                0
# um_unit_id                 0
# quantity                   0
# month                      0
# year                       0
# price                      0
# mp_commoditysource    956779
# dtype: int64

# %%
print(afp.isnull().sum())
# Out:
# Unnamed: 0                 0
# country_id                 0
# country                    0
# state_id                   0
# state                 126678
# market_id                  0
# market                     0
# produce_id                 0
# produce                    0
# currency_id                0
# currency                   0
# pt_id                      0
# market_type                0
# um_unit_id                 0
# quantity                   0
# month                      0
# year                       0
# price                      0
# mp_commoditysource    956779
# dtype: int64

# %%
rice_data = afp[afp['produce'] == 'Rice - Retail']
plt.figure(figsize=(12, 6))
sns.lineplot(data=rice_data, x='year', y='price', hue='month')
plt.xlabel('Year')
plt.ylabel('Price')
plt.title('Rice Prices Over Time')
plt.show()

# %%
plt.figure(figsize=(10, 6))
sns.histplot(data=afp, x='price', bins=30)
plt.xlabel('Price')
plt.ylabel('Frequency')
plt.title('Price Distribution')
plt.show()

# %%
milk_data = afp[afp['produce'] == 'Milk - Retail']
plt.figure(figsize=(10, 6))
sns.boxplot(data=milk_data, x='month', y='price')
plt.xlabel('Month')
plt.ylabel('Price')
plt.title('Milk Prices by Month')
plt.show()

# %%
average_prices = afp.groupby('produce')['price'].mean()
print(average_prices)
# Out:
# produce
# Apples (red) - Retail          1190.806780
# Apples - Retail                 318.400000
# Avocados - Retail               260.170797
# Bananas (imported) - Retail    1460.333333
# Bananas (local) - Retail        579.194653
#                                   ...
# Yam (yellow) - Retail           362.535103
# Yam - Retail                    347.818224
# Yam - Wholesale                6412.059156
# Yogurt - Retail                  23.107637
# Zucchini - Retail               274.504520
# Name: price, Length: 457, dtype: float64

# %% [markdown]
# # List 5 research questions from the dataset

# %% [markdown]
# ### 1 What is the average price of bread in Algiers, Algeria, and does it remain relatively stable throughout the year?
#
# ### 2. Is there a correlation between the price of rice and the price of bread at retail markets in Algiers, Algeria?
#
# ### 3. How does the price of rice at retail markets in Algeria vary over time, and are there any noticeable trends or patterns?
#
# ### 4. How does the quantity of rice sold in kilograms (KG) change throughout the year, and are there any seasonal fluctuations?
#
# ### 5. Are there any significant differences in the prices of rice and bread between the years 2015 and 2016 in Algiers, Algeria?

# %% [markdown]
# ##  What is the average price of bread in Algiers, Algeria, and does it remain relatively stable throughout the year?

# %%
bread_price_trend = afp.groupby(['year', 'month'])['price'].mean().reset_index()

# Plot the price trend
plt.figure(figsize=(12, 6))
plt.plot(bread_price_trend['year'].astype(str) + '-' + bread_price_trend['month'].astype(str), bread_price_trend['price'], marker='o', color='orange')
plt.title('Average Price of Bread Over Time')
plt.xlabel('Year-Month')
plt.ylabel('Average Price')
plt.xticks(rotation=45)
plt.grid(True)
plt.show()

# %% [markdown]
# ##  Is there a correlation between the price of rice and the price of bread at retail markets in Algiers, Algeria?

# %%
# Filter data for rice and bread
rice_data = afp[afp['produce'] == 'Rice - Retail']
bread_data = afp[afp['produce'] == 'Bread - Retail']

# Calculate correlation
correlation = rice_data['price'].corr(bread_data['price'])

# %% [markdown]
# ## How does the price of rice at retail markets in Algeria vary over time, and are there any noticeable trends or patterns?

# %%
import pandas as pd
import matplotlib.pyplot as plt

# Load the dataset
afp = pd.read_csv("datasets/africa_food_prices.csv")

# Filter data for rice
rice_data = afp[afp['produce'] == 'Rice - Retail']

# Group by year and month, calculate the total quantity sold
rice_quantity_trend = rice_data.groupby(['year', 'month'])['quantity'].sum().reset_index()

# Plot the quantity trend
plt.figure(figsize=(12, 6))
plt.plot(rice_quantity_trend['year'].astype(str) + '-' + rice_quantity_trend['month'].astype(str), rice_quantity_trend['quantity'], marker='o')
plt.title('Quantity of Rice Sold Over Time')
plt.xlabel('Year-Month')
plt.ylabel('Total Quantity Sold (KG)')
plt.xticks(rotation=45)
plt.grid(True)
plt.show()

# %% [markdown]
# ## Are there any significant differences in the prices of rice and bread between the years 2015 and 2016 in Algiers, Algeria?

# %%
from scipy import stats

# Filter data for rice and bread in 2015 and 2016
rice_2015 = rice_data[(rice_data['year'] == 2015)]['price']
rice_2016 = rice_data[(rice_data['year'] == 2016)]['price']

bread_data = afp[afp['produce'] == 'Bread - Retail']
bread_2015 = bread_data[(bread_data['year'] == 2015)]['price']
bread_2016 = bread_data[(bread_data['year'] == 2016)]['price']

# Perform t-tests
rice_t_statistic, rice_p_value = stats.ttest_ind(rice_2015, rice_2016)
bread_t_statistic, bread_p_value = stats.ttest_ind(bread_2015, bread_2016)

# Check p-values for significance
if rice_p_value < 0.05:
    print("There is a significant difference in rice prices between 2015 and 2016.")
else:
    print("There is no significant difference in rice prices between 2015 and 2016.")

if bread_p_value < 0.05:
    print("There is a significant difference in bread prices between 2015 and 2016.")
else:
    print("There is no significant difference in bread prices between 2015 and 2016.")
# Out:
# There is a significant difference in rice prices between 2015 and 2016.
# There is no significant difference in bread prices between 2015 and 2016.

# %% [markdown]
# ## 4. How does the quantity of rice sold in kilograms (KG) change throughout the year, and are there any seasonal fluctuations?

# %%
# Group by month and year, calculate the total quantity sold
rice_quantity_trend = rice_data.groupby(['year', 'month'])['quantity'].sum().reset_index()

# You can then visualize this trend with a line chart or plot

# %%
import pandas as pd
import matplotlib.pyplot as plt

# Assuming you already have rice_quantity_trend DataFrame

# Create a line chart
plt.figure(figsize=(12, 6))
plt.plot(rice_quantity_trend['year'].astype(str) + '-' + rice_quantity_trend['month'].astype(str), rice_quantity_trend['quantity'], marker='o')
plt.title('Quantity of Rice Sold Over Time')
plt.xlabel('Year-Month')
plt.ylabel('Total Quantity Sold (KG)')
plt.xticks(rotation=45)
plt.grid(True)
plt.show()
